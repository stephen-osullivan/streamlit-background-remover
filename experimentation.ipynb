# %%
from rembg import remove
from PIL import Image

# %%
input_path = 'images/animal-1.jpg'

input = Image.open(input_path)
input
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667>

# %%
output = remove(input)
# Downloading data from 'https://github.com/danielgatis/rembg/releases/download/v0.0.0/u2net.onnx' to file '/home/sos00/.u2net/u2net.onnx'.
output
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x667>
